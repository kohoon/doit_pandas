# %% [markdown]
# # 04 그래프 그리기

# %%
import pandas as pd

toc04 = pd.DataFrame(
    data={'내용': ['데이터 시각화가 필요한 이유', 'matplotlib 라이브러리 자유자재로 사용하기', 'seaborn 라이브러리 자유자재로 사용하기', '데이터프레임과 시리즈로 그래프 그리기', 'seaborn 라이브러리로 그래프 스타일 설정하기']},
    index=['04-1', '04-2', '04-3', '04-4', '04-5'])

print(toc04)

toc04
# Out:
#                                내용
# 04-1              데이터 시각화가 필요한 이유
# 04-2  matplotlib 라이브러리 자유자재로 사용하기
# 04-3     seaborn 라이브러리 자유자재로 사용하기
# 04-4         데이터프레임과 시리즈로 그래프 그리기
# 04-5  seaborn 라이브러리로 그래프 스타일 설정하기
#                                내용
# 04-1              데이터 시각화가 필요한 이유
# 04-2  matplotlib 라이브러리 자유자재로 사용하기
# 04-3     seaborn 라이브러리 자유자재로 사용하기
# 04-4         데이터프레임과 시리즈로 그래프 그리기
# 04-5  seaborn 라이브러리로 그래프 스타일 설정하기

# %% [markdown]
# ## 04-1 데이터 시각화가 필요한 이유

# %% [markdown]
# ## 앤스콤 4분할 그래프 살펴보기 : 데이터 시각화를 보여주는 전형적 사례. 데이터 시각화를 하지 않고, 수치만 볼 때 범할 수 있는 함정을 보여주는 그래프

# %% [markdown]
# # 1. 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# # 2. matplotlib 라이브러리로 간단한 그래프 그리기

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset_1['x'], dataset_1['y'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# #### matplotlib 라이브러리로 그래프 그리기
# #### 1) 전체 그래프가 위치할 기본 틀을 만듭니다.
# #### 2) 그래프를 그려 넣을 그래프 격자를 만듭니다.
# #### 3) 그런 다음 격자에 그래프를 하나씩 추가합니다. 격자에 그래프가 추가되는 순서는 왼쪽에서 오른쪽 방향입니다.
# #### 4) 만약 격자의 첫 번째 행이 꽉 차면 두 번째 행에 그래프를 그려 넣습니다.

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig.suptitle("Asscombe Data")
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %% [markdown]
# # 다변량 그래프 그리기

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# # 알아두면 좋아요
